# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','friedman_mse'],'max_features':['sqrt','log2'],'splitter':['best','random']}

grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

print("The R_Score value for the best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for the best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.010883      0.004885         0.004986        0.001715
# 1       0.005942      0.000954         0.003931        0.000203
# 2       0.005794      0.001345         0.003351        0.001530
# 3       0.005415      0.000859         0.003504        0.000885
# 4       0.007392      0.001032         0.004064        0.000071
# 5       0.006963      0.000837         0.004024        0.000001
# 6       0.007121      0.000762         0.003988        0.001068
# 7       0.005629      0.000715         0.003625        0.001082
#
#   param_criterion param_max_features param_splitter  \
# 0   squared_error               sqrt           best
# 1   squared_error               sqrt         random
# 2   squared_error               log2           best
# 3   squared_error               log2         random
# 4    friedman_mse               sqrt           best
# 5    friedman_mse               sqrt         random
# 6    friedman_mse               log2           best
# 7    friedman_mse               log2         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...           0.756665
# 1  {'criterion': 'squared_error', 'max_features':...           0.685591
# 2  {'criterion': 'squared_error', 'max_features':...           0.767303
# 3  {'criterion': 'squared_error', 'max_features':...           0.675714
# 4  {'criterion': 'friedman_mse', 'max_features': ...           0.694976
# 5  {'criterion': 'friedman_mse', 'max_features': ...           0.705347
# 6  {'criterion': 'friedman_mse', 'max_features': ...           0.707153
# 7  {'criterion': 'friedman_mse', 'max_features': ...           0.659982
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.653867           0.669824           0.734445           0.661953
# 1           0.606586           0.655516           0.681190           0.647119
# 2           0.617423           0.763946           0.645721           0.741755
# 3           0.547217           0.727454           0.665681           0.685802
# 4           0.640591           0.718270           0.746693           0.695005
# 5           0.520970           0.654438           0.588075           0.663239
# 6           0.666348           0.706556           0.658368           0.729612
# 7           0.568388           0.736624           0.730225           0.660047
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.695351        0.041895                3
# 1         0.655201        0.028382                7
# 2         0.707230        0.063033                1
# 3         0.660374        0.060356                6
# 4         0.699107        0.034899                2
# 5         0.626414        0.064746                8
# 6         0.693607        0.026953                4
# 7         0.671053        0.060967                5

# %%
age=int(input("Age:"))
bmi=int(input("BM:"))
childen_input=int(input("Childre:"))
sex_male=int(input("Sex Male true or false:"))
smoker_yes_input=int(input("smoker Yes True or False:"))
# Out:
# Age: 35
# BM: 24
# Childre: 3
# Sex Male true or false: 1
# smoker Yes True or False: 1

# %%
Future_Prediction=grid.predict([[age,bmi,childen_input,sex_male,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19361.9988]
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
